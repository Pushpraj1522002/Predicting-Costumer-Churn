# %% [markdown]
# <a href="https://colab.research.google.com/github/Pushpraj1522002/Predicting-Costumer-Churn/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Logistic Regression
#
# ---

# %% [markdown]
# In order to estimate the class of a data point, we need some sort of guidance on what would be the most probable class for that data point. For this, we use Logistic Regression.

# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
from sklearn import preprocessing
# %matplotlib inline 
import matplotlib.pyplot as pl

# %%
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/ChurnData.csv")
display(df)
# Out:
#      tenure   age  address  income   ed  employ  equip  callcard  wireless  \
# 0      11.0  33.0      7.0   136.0  5.0     5.0    0.0       1.0       1.0
# 1      33.0  33.0     12.0    33.0  2.0     0.0    0.0       0.0       0.0
# 2      23.0  30.0      9.0    30.0  1.0     2.0    0.0       0.0       0.0
# 3      38.0  35.0      5.0    76.0  2.0    10.0    1.0       1.0       1.0
# 4       7.0  35.0     14.0    80.0  2.0    15.0    0.0       1.0       0.0
# ..      ...   ...      ...     ...  ...     ...    ...       ...       ...
# 195    55.0  44.0     24.0    83.0  1.0    23.0    0.0       1.0       0.0
# 196    34.0  23.0      3.0    24.0  1.0     7.0    0.0       1.0       0.0
# 197     6.0  32.0     10.0    47.0  1.0    10.0    0.0       1.0       0.0
# 198    24.0  30.0      0.0    25.0  4.0     5.0    0.0       1.0       1.0
# 199    61.0  50.0     16.0   190.0  2.0    22.0    1.0       1.0       1.0
#
# ...

# %%
dff=df[["ed","employ","equip","callcard","wireless"]]
display(dff)
# Out:
#       ed  employ  equip  callcard  wireless
# 0    5.0     5.0    0.0       1.0       1.0
# 1    2.0     0.0    0.0       0.0       0.0
# 2    1.0     2.0    0.0       0.0       0.0
# 3    2.0    10.0    1.0       1.0       1.0
# 4    2.0    15.0    0.0       1.0       0.0
# ..   ...     ...    ...       ...       ...
# 195  1.0    23.0    0.0       1.0       0.0
# 196  1.0     7.0    0.0       1.0       0.0
# 197  1.0    10.0    0.0       1.0       0.0
# 198  4.0     5.0    0.0       1.0       1.0
# 199  2.0    22.0    1.0       1.0       1.0
#
# [200 rows x 5 columns]

# %%
churn_dff = df[["ed","employ","equip","callcard","wireless"]]
churn_dff.head(10)

X = np.asanyarray(churn_dff[["ed","employ","equip","callcard","wireless"]])
X[0:5]

y = np.asanyarray(df['churn'])
y [0:5]

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR

yhat = LR.predict(X_test)
yhat

yhat_prob = LR.predict_proba(X_test)
yhat_prob

confusion_matrix(y_test, yhat)
# Out:
# Train set: (160, 5) (160,)
# Test set: (40, 5) (40,)
# array([[18,  7],
#        [ 9,  6]])

# %% [markdown]
# Accuracy of 60.0%

# %%
churn_dff = df[["loglong","address","callcard","wireless"]]
churn_dff.head(10)

X = np.asanyarray(churn_dff[["loglong","address","callcard","wireless"]])
X[0:5]

y = np.asanyarray(df['churn'])
y [0:5]

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR

yhat = LR.predict(X_test)
yhat

yhat_prob = LR.predict_proba(X_test)
yhat_prob

confusion_matrix(y_test, yhat)
# Out:
# Train set: (160, 4) (160,)
# Test set: (40, 4) (40,)
# array([[23,  2],
#        [11,  4]])

# %% [markdown]
# Accuracy of 67.5%

# %%
churn_dff = df[["income","loglong","lninc","logtoll"]]
churn_dff.head(10)

X = np.asanyarray(churn_dff[["income","loglong","lninc","logtoll"]])
X[0:5]

y = np.asanyarray(df['churn'])
y [0:5]

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR

yhat = LR.predict(X_test)
yhat

yhat_prob = LR.predict_proba(X_test)
yhat_prob

confusion_matrix(y_test, yhat)
# Out:
# Train set: (160, 4) (160,)
# Test set: (40, 4) (40,)
# array([[24,  1],
#        [14,  1]])

# %% [markdown]
# Accuracy of 62.5%

# %%
churn_dff = df[["longmon","loglong","ed","logtoll"]]
churn_dff.head(10)

X = np.asanyarray(churn_dff[["longmon","loglong","ed","logtoll"]])
X[0:5]

y = np.asanyarray(df['churn'])
y [0:5]

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR

yhat = LR.predict(X_test)
yhat

yhat_prob = LR.predict_proba(X_test)
yhat_prob

confusion_matrix(y_test, yhat)
# Out:
# Train set: (160, 4) (160,)
# Test set: (40, 4) (40,)
# array([[24,  1],
#        [11,  4]])

# %% [markdown]
# Accuracy of 70.0%

# %%
churn_dff = df[["tenure","callcard","ed","custcat","lninc"]]
churn_dff.head(10)

X = np.asanyarray(churn_dff[["tenure","callcard","ed","custcat","lninc"]])
X[0:5]

y = np.asanyarray(df['churn'])
y [0:5]

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR

yhat = LR.predict(X_test)
yhat

yhat_prob = LR.predict_proba(X_test)
yhat_prob

confusion_matrix(y_test, yhat)
# Out:
# Train set: (160, 5) (160,)
# Test set: (40, 5) (40,)
# array([[23,  2],
#        [10,  5]])

# %% [markdown]
# Accuracy of 70.0%
